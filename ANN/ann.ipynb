# %%
import pandas as pd
df=pd.read_csv('wine.csv')
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.preprocessing import StandardScaler
x_sc=StandardScaler().fit_transform(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_sc,y,test_size=0.33)

# %%
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier(hidden_layer_sizes=(20,10),random_state=1,max_iter=800)
mlp.fit(x_train,y_train)
y_pred=mlp.predict(x_test)
print('Prediction of [12.29,3.17,2.21,18,88,2.85,2.99,0.45,2.81,2.3,1.42,2.83,406] : ',mlp.predict([[12.29,3.17,2.21,18,88,2.85,2.99,0.45,2.81,2.3,1.42,2.83,406]]))
# Out:
# Prediction of [12.29,3.17,2.21,18,88,2.85,2.99,0.45,2.81,2.3,1.42,2.83,406] :  [1]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score,recall_score,precision_score,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
cm=confusion_matrix(y_test,y_pred)
print('Confusion Matrix\n',cm)
cm_display=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['class_1','class_2','class_3'])
cm_display.plot()
print('Accuracy Score = ',accuracy_score(y_test,y_pred)*100,'\nF1 Score = ',f1_score(y_test,y_pred,average='macro'),'\nRecall Score = ',recall_score(y_test,y_pred,average='macro'),'\nPrecision Score = ',precision_score(y_test,y_pred,average='macro'))
# Out:
# Confusion Matrix
#  [[19  0  0]
#  [ 0 26  1]
#  [ 0  1 12]]
# Accuracy Score =  96.61016949152543
# F1 Score =  0.9620132953466287
# Recall Score =  0.9620132953466287
# Precision Score =  0.9620132953466287
